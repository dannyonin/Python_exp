# %% [markdown]
# <a href="https://colab.research.google.com/github/dannyonin/Python_exp/blob/main/Python_Exersice_on_collab_page_1_basic.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #Intro 📚 😎
#
#
#
#
# ##Welcome to the BASICS section!
#
#
#
# We'll start with simple exercises to warm up a bit 💪 🔽

# %% [markdown]
# ---
# ####Exercise 0
# Print the Python version to the console.
#
#
#
# **Expected result:**
#
#
#
# `3.8.10`

# %%
import sys

print(sys.version.split()[0])

# %% [markdown]
# ---
# #### Exercise 1
# Using the `print()` function, print string: `'Learn Python!'` to the console.

# %%
print('Learn Python!')

# %% [markdown]
# ---
# #### Exercise 2
# Assign to the variable age number 20. Using the age variable and the `print()` function print to the console the following text:
#
#
#
# `I am 20 years old.`

# %%
age = 20
print("I am {} years old.".format(age))

# %% [markdown]
# ---
# #### Exercise 3
# Create two variables (you can freely choose the names) and assign to them following values:
#
# *  'Python'
# *  '3.8'
#
# Using these variables and the print() function, print to the console the following text:
#
#
# `I am learning Python version 3.8`

# %%
b = 3.8
a = "Python"

print("I am learning {} version {}".format(a, b))

# %% [markdown]
# ---
# #### Exercise 4
# Assign 199.99 to the price variable and check the solution.
#
#
#
# Expected result:
#
#
#
# `This costs 199.99`

# %%
price = 199.99
print('This costs', price)

# %% [markdown]
# ---
# ####Exercise 5
# Assign 69.99 to the price variable and check the solution.
#
#
#
# **Expected result:**
#
#
#
# This costs 69.99

# %%
price = 69.99
print(f'This costs {price}')

# %% [markdown]
# ---
# ####Exercise 6
# Assign two variables that store the following values:
#
# - $ 34.99 - product price *(float)*
#
# - 20 lbs - product weight *(int)*
#
#
#
# Using the f-string formatting style print to the console the following message:
#
#
#
# `Price: $34.99. Weight: 20 lbs.`

# %%
price = 34.99
weight = 20

print("Price: ${}. Weight: {} lbs.".format(price , weight))

# %% [markdown]
# ---
# ####Exercise 7
# Below is an approximation of pi:
#
#
#
# `pi = 3.1415926535`
#
#
# Using f-string formatting, print the approximation of pi to two decimal places as shown below.
#
#
# **Expected result:**
#
#
#
# `Pi: 3.14`

# %%
pi = 3.1415926535

print(f'Pi: {pi:.2f}')

# %% [markdown]
# ---
# ####Exercise 8
# Using three print() function (one line - one function) print the following text:
#
#
#
#
# ```
# ----------------------------------------
# VERSION: 1.0.1
# ----------------------------------------
#
# ```
#
#
#
# **Tip:** The lines consist of 40 dash characters: `'-'`.

# %%
print('-'*40)
print("VERSION: 1.0.1")
print('-'*40)

# %% [markdown]
# ---
# ###Exercise 9
# Using the four print() function (one line - one function) print the following text:
#
#
# ```
# ========================================
# author: johnsmith@sample.com
# date: 01-01-2021
# ========================================
#
# ```
#
#
#
# **Tip:** The lines consist of 40 equal signs: `'='`.

# %%
from datetime import date

print("="*40)
print("author: johnsmith@sample.com")
print("date: 01-01-2021")
print("="*40)

# %% [markdown]
# ---
# ###Exercise 10
# Using the `print()` function and the sep argument set to '#' print the following text:
#
#
#
# `'summer#time#holiday'`

# %%
print("summer" ,"time", "holiday", sep="#")

# %% [markdown]
# ---
# ###Exercise 11
# Write a program that calculates the area of a circle with a radius = 5. Use an approximate value of pi:
#
# `pi = 3.14`
#
# Print the result to the console as shown below.
#
# **Expected result:**
#
# `Area: 78.5`

# %%
pi = 3.14
radius = 5

Area = pi * radius **2
print(f'Area: {Area}')

# %% [markdown]
# ---
# ###Exercise 12
# Write a program that calculates the future value of 1000 USD with an annual interest rate of 3%, annual capitalization and a 5-year investment period. Round the result to the nearest cent.
#
#
#
# **Tip:** Use compound capitalization of interest.
#
#
#
# Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
# `The future value of the investment: 1159.27 USD`

# %%
year_of_invesment = 5
annual_interest = 0.03
amount = 1_000
total = 0
total = amount * (1+annual_interest) ** year_of_invesment
print(f'The future value of the investment: {total:.2f} USD')

# %% [markdown]
# ---
# ###Exercise 13
# Write a program that calculates the delta for the quadratic equation:
#
# ![2020-04-01_17-16-03-f72c236ec801d4e7b1502d7be61016f9.jpg](data:image/jpeg;base64,...)
#
# Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
# `Delta: 4`

# %%
a = 3
b = -4
c = 1

delta = b**2- 4 * a * c
print(f'Delta: {delta}')

# %% [markdown]
# ---
# ###Exercise 14
# The arithmetic sequence is given with the following formula:
#
# ![2020-04-01_17-14-12-3352b824d2bcd36a960aa1049736ef51.jpg](data:image/jpeg;base64,...)
#
#
#
# Calculate the sum of the first ten elements of this sequence. Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
# `The sum of the first 10 elements in a sequence: 320.0`

# %%
a = 0

for n in range(1, 11):
    a = a + 10 + 4 * n
    
print(f"The sum of the first 10 elements in a sequence: {a:.1f}" )

# %% [markdown]
# ---
# ###Exercise 15
# The geometric sequence is given with the following formula:
#
# ![2020-04-01_17-23-56-61fbafc209398d621f1c3ce36e5d05f9.jpg](data:image/jpeg;base64,...)
#
#
#
# Calculate the sum of the first six elements of this sequence. Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
# `The sum of the first 6 elements of the sequence is: 504.0`

# %%
a = 0
for n in range(1,7):
    a = a + 8 * (2 **(n-1))

print(f'The sum of the first 6 elements of the sequence is: {float(a)}')

# %% [markdown]
# ---
# ###Exercise 16
# The quadratic equation is given with the following formula:
#
# ![2020-04-01_17-37-18-dcc78ed303a832b100ef84ce35646ec4.jpg](data:image/jpeg;base64,...)
#
#
# Using Vieta's formulas calculate the sum and product of the roots of this quadratic equation. Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
#
#
# ```
# x1 + x2 = -5.0
# x1x2 = 4.0
# ```

# %%
a=1
b=5
c=4
x1 = (-b + (b**2 - 4 * a * c ) ** 0.5 )/ 2* a
x2 = (-b - (b**2 - 4 * a * c ) ** 0.5 )/2 * a

print(f'x1 + x2 = {x1+x2}')
print(f'x1x2 = {x1*x2}')

# %% [markdown]
# ---
# ###Exercise 17
# Calculate the midpoint of the segment with ends at the points: A = (2, 4), B = (-4, 6) and print result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
# `The middle point: (-1.0, 5.0)`

# %% [markdown]
# solution 1:

# %%
x1=2
x2=-4
y1=4
y2=6

mid = ((x1+x2)/2, (y1+y2)/2)
print(f'The middle point: {mid}')

# %% [markdown]
# solution 2:

# %%
a1 = 2
a2 = 4
b1 = -4
b2 = 6

s1 = (a1 + b1) / 2
s2 = (a2 + b2) / 2
print(f'The middle point: ({s1}, {s2})')

# %% [markdown]
# ---
# ###Exercise 18
# Calculate the distance of two points A = (3, 2), B = (- 1, -1) and print result to the console as shown below.
#
#
#
#
# **Expected result:**
#
#
# `The distance between points A and B: 5.0`

# %% [markdown]
# ---
# ###Exercise 19
# Find the roots of the quadratic equation:
#
# ![2020-04-01_18-10-21-9c7f3adf97e34a3f3b70a8e7ffa6c01c.jpg](data:image/jpeg;base64,...)
#
# Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
#
# ```
# x1 = -4.0
# x2 = -1.0
#
# ```

# %% [markdown]
# ---
# ###Exercise 20
# Calculate the geometric mean of the following numbers:` 4, 3, 4.5, 5` and print result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
#
# `Geometric average of the given numbers: 4.05`

# %% [markdown]
# ___
# ###Exercise 21
# An infinite geometric sequence is given with the following formula:
#
# ![2020-04-02_07-43-01-3934206ae40d576e473a036c0b35cdac.jpg](data:image/jpeg;base64,...)
#
#
#
#
# Calculate the sum of this sequence. Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
# `The sum of the sequence: 2.0`

# %% [markdown]
# ---
# ###Exercise 22
# Calculate the standard deviation of the following set of data: `10, 11, 9`.
#
# Print the result to the console as shown below.
#
#
#
# **Expected result:**
#
#
#
# `The standard deviation: 0.82`
